# %%
import pandas as pd
import re

# %%
data = pd.read_csv('/content/sample_data/video_games.txt')
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# Как критики относятся к спортивным играм?
# Гипотезы
#
# H0 = оценка критиков по спортивным играм <= 5 H1 = оценка критиков по спортивным играм > 5

# %%
sports_filterd = data[data['Genre'] == 'Sports']
sports_filterd[sports_filterd['Critic_Score'].notna()]['Critic_Score']
# Out:
# 0        76.0
# 3        80.0
# 13       80.0
# 15       80.0
# 77       82.0
#          ...
# 16456    78.0
# 16478    57.0
# 16532    78.0
# 16550    78.0
# 16555    88.0
# Name: Critic_Score, Length: 1194, dtype: float64

# %%
from scipy import stats as st
alpha = 0.05
result = st.ttest_1samp(sports_filterd[sports_filterd['Critic_Score'].notna()]['Critic_Score'], 5, alternative='greater')

print(sports_filterd[sports_filterd['Critic_Score'].notna()]['Critic_Score'].mean())
print(result)

if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу, средняя оценка больше 5')
else:
    print('Не отвергаем нулевую нулевую гипотезу, спортивные игры не нравятся критикам')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-28a3744771eb> in <module>()
#       1 from scipy import stats as st
#       2 alpha = 0.05
# ----> 3 result = st.ttest_1samp(sports_filterd[sports_filterd['Critic_Score'].notna()]['Critic_Score'], 5, alternative ='greater')
#       4
#       5 print(sports_filterd[sports_filterd['Critic_Score'].notna()]['Critic_Score'].mean())
#
# TypeError: ttest_1samp() got an unexpected keyword argument 'alternative'
